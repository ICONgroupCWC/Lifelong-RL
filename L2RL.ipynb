# %%
# importing libraries

import torch                  # providing neural network (NN) building
import torch.nn as nn         # providing classes and functions for building NNs
import torch.optim as optim   # optimizers needed for adjusting model parameters to minimize the loss through training NNs 
import numpy as np            # preprocessing data before feeding it into models
import random                 # providing functions for generating random numbers, initializing weights
import math                   # essential mathematical operations to complement operations in Pytorch or Numpy
from collections import deque # importing "deque" class from "collections" module, data structure for fast appends and pops from both sides.
                              # storing and replaying recent experiences in reinforcement learning (RL) 
                              #to implement a replay memeort and improve model stability

# initil parameters
time_steps                = 200           # number of time steps in each learning episode
episodes                  = 1000          # number of learning episodes
P_pludged_in              = 0.0400        # pludged in power for Tx1 in watt
TX2_communication_Power   = 0.0100        # transmission power for Tx2 in watt
commnucation_distance     = 800           # Tx1-Rx1 distance in meter and Tx2-Rx2 distance in meter
EnergyHarvesting_distance = 10            # Tx1-Tx2 distance in meter 
Fading_samples            = 10            # number of fading samples for communication and energy harvesting (EH) channels        
Noise_Power               = pow(10,-15)   # noise power in watt
Bandwidth                 = 5 * pow(10,6) # communication bandwidth in Hz
Theta_1                   = pow(10,7)     # predefined data threshold in bits for Tx1 data buffer           
Theta_2                   = pow(10,7)     # predefined data threshold in bits for Tx2 data buffer 
B_Max                     = 0.003         # battery capacity in Joul
EnergyHarvestinmg_eta     = 0.1           # power conversion efficiency for EH receiver
lambda_1                  = pow(10,6)     # density of arrival data for Tx1
lambda_2                  = pow(10,6)     # density of arrival data for Tx2
ALPHA                     = 2             # Path-loss exponent for communication and EH channels 
penalty_weight            = 0.5           # to define the importance of the objective function (energy consumption) and constraints for queueing stability
Reward_episoeds           = np.zeros(episodes)

# Rayleigh fading channel model
def FadingChannel(TX_Power, distance, ALPHA, fading_samples):
    fading         = np.random.normal(0, 1, fading_samples) + 1j * np.random.normal(0, 1, fading_samples)
    received_power = TX_Power * pow(distance, -ALPHA) * np.abs(fading)**2
    RX_Power       = np.mean(received_power)
    channel_gain   = pow(distance, -ALPHA) * np.abs(fading)**2
    return RX_Power, channel_gain

# data transfer model 
def calculate_transferred_data(Received_Power, Noise_Power, Bandwidth, communication_time):
    SNR  = Received_Power / Noise_Power
    Rate = Bandwidth * math.log2(1 + SNR)
    Data = Rate * communication_time
    return SNR, Rate, Data

# Define the environment and the agent
# class: a blueprint for creating objects, which can have attributes (data) and methods (functions)
class Environment: 
    # initializing environment's state to a specific value at the start
    def __init__(self, EnergyHarvestinmg_eta):
        self.EnergyHarvestinmg_eta = EnergyHarvestinmg_eta           
        self.state = self.reset() 

    # initializing variables and then combining them into a NumPy array representing the state of an instance of the Environment class
    def reset(self):
        B_t = 0.0
        h1_t = np.random.exponential(1)
        h2_t = np.random.exponential(1)
        heh_t = np.random.exponential(1)
        Q1_t = 0.0
        Q2_t = 0.0
        self.state = np.array([B_t, heh_t, h1_t, h2_t, Q1_t, Q2_t])
        return self.state

    # simulating one step of an environment based on a given action
    # updating the environment's state
    # calculating reward
    # returning key information about the step
    def step(self, action):
        
        P_t1, tau1, tau_eh, tau2 = action # 4 variables in action

        # Each value in action is constrained to a certain range
        P_t1   = np.clip(P_t1, 0.0001, P_pludged_in)
        tau1   = np.clip(tau1, 0, 1)
        tau_eh = np.clip(tau_eh, 0, 1)
        tau2   = np.clip(tau2, 0, 1)

        # Ensure constraint: tau1 + tau_eh + tau2 <= 1 (communication round round duration)
        if tau1 + tau_eh + tau2 > 1:
            norm_factor = tau1 + tau_eh + tau2
            tau1       /= norm_factor
            tau_eh     /= norm_factor
            tau2       /= norm_factor

        # Channel model
        RX1_Power, Tx1_channel_gain = FadingChannel(P_t1, commnucation_distance, ALPHA, Fading_samples)
        RX2_Power, Tx2_channel_gain = FadingChannel(TX2_communication_Power, commnucation_distance, ALPHA, Fading_samples)
        EH_Power, EH_channel_gain   = FadingChannel(P_pludged_in - P_t1, EnergyHarvesting_distance, ALPHA, Fading_samples)

        # Transmitted data
        SNR1, Rate1, D1_t = calculate_transferred_data(RX1_Power, Noise_Power, Bandwidth, tau1)
        SNR2, Rate2, D2_t = calculate_transferred_data(RX2_Power, Noise_Power, Bandwidth, tau2)

        # Update the queues
        Q1_t_new = max(0, self.state[4] - D1_t) + np.random.poisson(lambda_1)
        Q2_t_new = max(0, self.state[5] - D2_t) + np.random.poisson(lambda_2)

        # Calculate harvested energy
        P_harvested = EnergyHarvestinmg_eta * EH_Power * tau_eh

        # Update the battery level
        B_t_new = max(0, min(B_Max, self.state[0] - TX2_communication_Power * tau2 + P_harvested))
        
        # Calculate the reward
        reward = -(P_t1*tau1 + TX2_communication_Power*tau2) - penalty_weight*(self.state[4]-D1_t + self.state[5]-D2_t)

        # Update the state
        self.state = np.array([B_t_new, np.random.exponential(1), np.random.exponential(1), np.random.exponential(1), Q1_t_new, Q2_t_new])
        
        return self.state, reward

# defining the NN model for Deep Q-Network (DQN) to approximate the Q-value function
class DQN(nn.Module): # defining a new class DQN that inherits from nn.Module, making it a NN model in PyTorch
    # the DQN class is a fully connected NN
    # to approximate the Q-values for each possible action in the RL setting

    # initializing the network layers and setting up the architecture
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_size, 64)  # first fully connected (dense) layer
        self.fc2 = nn.Linear(64, 64)          # hidden layer
        self.fc3 = nn.Linear(64, action_size) # output layer

    # how data flows through the network, from input to output. This is where the actual computation happens.
    def forward(self, x):

        # The input x passes through the first layer (fc1)
        # followed by a ReLU activation function (torch.relu)
        # ReLU introduces non-linearity, helping the network learn complex patterns.
        x = torch.relu(self.fc1(x))

        # The output from the first layer is passed through the second layer (fc2), again followed by a ReLU activation.
        x = torch.relu(self.fc2(x))

        # the output of the second layer is passed through the last layer (fc3) without any activation function
        # resulting in action_size values representing Q-values for each action
        return self.fc3(x)

# Set up the training loop
# training the DQN model on a given environment (env)
# implementing the training loop for the RL agent

def train_dqn(env, episodes, initial_EnergyHarvestinmg_eta, gamma=0.99, epsilon=1.0, epsilon_min=0.01, epsilon_decay=0.995, batch_size=32):

    # env: The environment the agent interacts with.
    # episodes: The number of training episodes.
    # gamma: The discount factor for future rewards.
    # epsilon: Initial exploration rate (for epsilon-greedy policy).
    # epsilon_min: Minimum exploration rate to ensure the agent keeps exploring a little.
    # epsilon_decay: Rate at which epsilon decays after each episode.
    # batch_size: Size of the minibatch sampled from memory for training.

    env.EnergyHarvestinmg_eta = initial_EnergyHarvestinmg_eta
    state_size   = env.state.shape[0]
    action_size  = 4 

    # A deque (double-ended queue) that stores past experiences as tuples (state, action, reward, next_state) with a max length of 2000
    # This allows the agent to learn from past actions by sampling from memory.
    memory       = deque(maxlen=2000)

    # The main DQN that learns the Q-values
    model        = DQN(state_size, action_size)

    # A copy of model used for stable target generation. It is updated periodically to match model.
    target_model = DQN(state_size, action_size)
    target_model.load_state_dict(model.state_dict())

    # Adam optimizer for updating model parameters.
    optimizer    = optim.Adam(model.parameters())

    # Mean Squared Error (MSE) loss, used to measure the difference between the predicted Q-value and the target Q-value.
    criterion    = nn.MSELoss()

    for episode in range(episodes):
        state = env.reset()
        total_reward = 0

        if episode == episodes/2:
            env.EnergyHarvestinmg_eta = initial_EnergyHarvestinmg_eta * 100

        for t in range(time_steps):
            if np.random.rand() <= epsilon:
                action = np.random.rand(action_size)
                action[0] = action[0] * P_pludged_in  # Scale P_t1 to be in the correct range
            else:
                action = model(torch.tensor(state, dtype=torch.float32)).detach().numpy()
                action[0] = np.clip(action[0], 0.0001, P_pludged_in)  # Ensure P_t1 stays within bounds
            
            next_state, reward = env.step(action)
            total_reward += reward

            memory.append((state, action, reward, next_state))
            state = next_state

            if len(memory) > batch_size:
                minibatch = random.sample(memory, batch_size)
                for s, a, r, s_next in minibatch:
                    target = r + gamma * torch.max(target_model(torch.tensor(s_next, dtype=torch.float32))).item()
                    target_f = model(torch.tensor(s, dtype=torch.float32))
                    target_f = torch.tensor(a, dtype=torch.float32) * target

                    loss = criterion(model(torch.tensor(s, dtype=torch.float32)), target_f)
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

            if t % 10 == 0:
                target_model.load_state_dict(model.state_dict())

        if epsilon > epsilon_min:
            epsilon *= epsilon_decay
        
        print(f'Episode {episode}/{episodes} - Total Reward: {total_reward/time_steps:.2f}, Epsilon: {epsilon:.2f}')

        Reward_episoeds[episode]         = total_reward/time_steps
    
    return Reward_episoeds

initial_EnergyHarvestinmg_eta = 0.1
env = Environment(initial_EnergyHarvestinmg_eta)
Reward_episoeds = train_dqn(env, episodes, EnergyHarvestinmg_eta)
np.save('reward_L2RL.npy', Reward_episoeds)
# Out:
# Episode 0/1000 - Total Reward: 38646984.62, Epsilon: 0.99
# Episode 1/1000 - Total Reward: 38139285.38, Epsilon: 0.99
# Episode 2/1000 - Total Reward: 40366227.53, Epsilon: 0.99
# Episode 3/1000 - Total Reward: 40164120.31, Epsilon: 0.98
# Episode 4/1000 - Total Reward: 38978705.05, Epsilon: 0.98
# Episode 5/1000 - Total Reward: 38088199.42, Epsilon: 0.97
# Episode 6/1000 - Total Reward: 38690848.98, Epsilon: 0.97
# Episode 7/1000 - Total Reward: 40232315.68, Epsilon: 0.96
# Episode 8/1000 - Total Reward: 39284937.16, Epsilon: 0.96
# Episode 9/1000 - Total Reward: 39327690.97, Epsilon: 0.95
# Episode 10/1000 - Total Reward: 39522118.36, Epsilon: 0.95
# Episode 11/1000 - Total Reward: 39936044.20, Epsilon: 0.94
# Episode 12/1000 - Total Reward: 39515945.73, Epsilon: 0.94
# Episode 13/1000 - Total Reward: 39724291.61, Epsilon: 0.93
# Episode 14/1000 - Total Reward: 37348126.04, Epsilon: 0.93
# Episode 15/1000 - Total Reward: 38517704.55, Epsilon: 0.92
# Episode 16/1000 - Total Reward: 38813333.68, Epsilon: 0.92
# Episode 17/1000 - Total Reward: 40733971.63, Epsilon: 0.91
# Episode 18/1000 - Total Reward: 38264751.80, Epsilon: 0.91
# Episode 19/1000 - Total Reward: 39603680.99, Epsilon: 0.90
# Episode 20/1000 - Total Reward: 38465628.90, Epsilon: 0.90
# Episode 21/1000 - Total Reward: 39279795.66, Epsilon: 0.90
# Episode 22/1000 - Total Reward: 39993286.70, Epsilon: 0.89
# Episode 23/1000 - Total Reward: 39587813.74, Epsilon: 0.89
# Episode 24/1000 - Total Reward: 38931229.84, Epsilon: 0.88
# Episode 25/1000 - Total Reward: 39582896.45, Epsilon: 0.88
# Episode 26/1000 - Total Reward: 40331009.26, Epsilon: 0.87
# Episode 27/1000 - Total Reward: 40129254.05, Epsilon: 0.87
# Episode 28/1000 - Total Reward: 40692734.71, Epsilon: 0.86
# Episode 29/1000 - Total Reward: 39811659.89, Epsilon: 0.86
# Episode 30/1000 - Total Reward: 38342857.98, Epsilon: 0.86
# Episode 31/1000 - Total Reward: 38750169.04, Epsilon: 0.85
# Episode 32/1000 - Total Reward: 39373406.81, Epsilon: 0.85
# Episode 33/1000 - Total Reward: 39505133.87, Epsilon: 0.84
# Episode 34/1000 - Total Reward: 40109949.29, Epsilon: 0.84
# Episode 35/1000 - Total Reward: 41210933.20, Epsilon: 0.83
# Episode 36/1000 - Total Reward: 39601673.78, Epsilon: 0.83
# Episode 37/1000 - Total Reward: 39262244.59, Epsilon: 0.83
# Episode 38/1000 - Total Reward: 40085965.94, Epsilon: 0.82
# Episode 39/1000 - Total Reward: 39657223.77, Epsilon: 0.82
# Episode 40/1000 - Total Reward: 39419877.94, Epsilon: 0.81
# Episode 41/1000 - Total Reward: 37841472.53, Epsilon: 0.81
# Episode 42/1000 - Total Reward: 40793930.04, Epsilon: 0.81
# Episode 43/1000 - Total Reward: 39505714.91, Epsilon: 0.80
# Episode 44/1000 - Total Reward: 39824194.28, Epsilon: 0.80
# Episode 45/1000 - Total Reward: 38755036.40, Epsilon: 0.79
# Episode 46/1000 - Total Reward: 41050161.32, Epsilon: 0.79
# Episode 47/1000 - Total Reward: 39156103.29, Epsilon: 0.79
# Episode 48/1000 - Total Reward: 39405376.29, Epsilon: 0.78
# Episode 49/1000 - Total Reward: 39964479.73, Epsilon: 0.78
# Episode 50/1000 - Total Reward: 40355917.31, Epsilon: 0.77
# Episode 51/1000 - Total Reward: 39743161.81, Epsilon: 0.77
# Episode 52/1000 - Total Reward: 39961103.78, Epsilon: 0.77
# Episode 53/1000 - Total Reward: 39600624.44, Epsilon: 0.76
# Episode 54/1000 - Total Reward: 39780699.13, Epsilon: 0.76
# Episode 55/1000 - Total Reward: 39220489.62, Epsilon: 0.76
# Episode 56/1000 - Total Reward: 38784255.30, Epsilon: 0.75
# Episode 57/1000 - Total Reward: 40526177.96, Epsilon: 0.75
# Episode 58/1000 - Total Reward: 40788877.18, Epsilon: 0.74
# Episode 59/1000 - Total Reward: 39553943.85, Epsilon: 0.74
# Episode 60/1000 - Total Reward: 40054696.23, Epsilon: 0.74
# Episode 61/1000 - Total Reward: 41002595.63, Epsilon: 0.73
# Episode 62/1000 - Total Reward: 40143939.04, Epsilon: 0.73
# Episode 63/1000 - Total Reward: 38997778.35, Epsilon: 0.73
# Episode 64/1000 - Total Reward: 39477583.57, Epsilon: 0.72
# Episode 65/1000 - Total Reward: 39175872.15, Epsilon: 0.72
# Episode 66/1000 - Total Reward: 38754468.08, Epsilon: 0.71
# Episode 67/1000 - Total Reward: 40255748.19, Epsilon: 0.71
# Episode 68/1000 - Total Reward: 39059891.87, Epsilon: 0.71
# Episode 69/1000 - Total Reward: 38957347.97, Epsilon: 0.70
# Episode 70/1000 - Total Reward: 38556370.64, Epsilon: 0.70
# Episode 71/1000 - Total Reward: 39921991.82, Epsilon: 0.70
# Episode 72/1000 - Total Reward: 40902640.21, Epsilon: 0.69
# Episode 73/1000 - Total Reward: 39895232.87, Epsilon: 0.69
# Episode 74/1000 - Total Reward: 40457160.13, Epsilon: 0.69
# Episode 75/1000 - Total Reward: 40313273.31, Epsilon: 0.68
# Episode 76/1000 - Total Reward: 39963264.58, Epsilon: 0.68
# Episode 77/1000 - Total Reward: 40734404.42, Epsilon: 0.68
# Episode 78/1000 - Total Reward: 39972441.25, Epsilon: 0.67
# Episode 79/1000 - Total Reward: 39170338.87, Epsilon: 0.67
# Episode 80/1000 - Total Reward: 40721139.79, Epsilon: 0.67
# Episode 81/1000 - Total Reward: 41121590.62, Epsilon: 0.66
# Episode 82/1000 - Total Reward: 40891635.73, Epsilon: 0.66
# Episode 83/1000 - Total Reward: 40777882.11, Epsilon: 0.66
# Episode 84/1000 - Total Reward: 39554562.51, Epsilon: 0.65
# Episode 85/1000 - Total Reward: 39476366.14, Epsilon: 0.65
# Episode 86/1000 - Total Reward: 40266374.59, Epsilon: 0.65
# Episode 87/1000 - Total Reward: 39444961.06, Epsilon: 0.64
# Episode 88/1000 - Total Reward: 40429538.92, Epsilon: 0.64
# Episode 89/1000 - Total Reward: 39805369.36, Epsilon: 0.64
# Episode 90/1000 - Total Reward: 41615646.84, Epsilon: 0.63
# Episode 91/1000 - Total Reward: 40824243.99, Epsilon: 0.63
# Episode 92/1000 - Total Reward: 39653381.33, Epsilon: 0.63
# Episode 93/1000 - Total Reward: 40050641.00, Epsilon: 0.62
# Episode 94/1000 - Total Reward: 40483905.96, Epsilon: 0.62
# Episode 95/1000 - Total Reward: 40874036.41, Epsilon: 0.62
# Episode 96/1000 - Total Reward: 40310777.84, Epsilon: 0.61
# Episode 97/1000 - Total Reward: 40163423.68, Epsilon: 0.61
# Episode 98/1000 - Total Reward: 40778121.03, Epsilon: 0.61
# Episode 99/1000 - Total Reward: 40612165.12, Epsilon: 0.61
# Episode 100/1000 - Total Reward: 41206010.66, Epsilon: 0.60
# Episode 101/1000 - Total Reward: 40762244.82, Epsilon: 0.60
# Episode 102/1000 - Total Reward: 38401197.36, Epsilon: 0.60
# Episode 103/1000 - Total Reward: 40684970.22, Epsilon: 0.59
# Episode 104/1000 - Total Reward: 39978499.80, Epsilon: 0.59
# Episode 105/1000 - Total Reward: 39034218.52, Epsilon: 0.59
# Episode 106/1000 - Total Reward: 40435130.04, Epsilon: 0.58
# Episode 107/1000 - Total Reward: 40306851.20, Epsilon: 0.58
# Episode 108/1000 - Total Reward: 39301373.90, Epsilon: 0.58
# Episode 109/1000 - Total Reward: 39154135.92, Epsilon: 0.58
# Episode 110/1000 - Total Reward: 39820603.08, Epsilon: 0.57
# Episode 111/1000 - Total Reward: 39227042.13, Epsilon: 0.57
# Episode 112/1000 - Total Reward: 40480524.94, Epsilon: 0.57
# Episode 113/1000 - Total Reward: 40278376.04, Epsilon: 0.56
# Episode 114/1000 - Total Reward: 40306473.79, Epsilon: 0.56
# Episode 115/1000 - Total Reward: 39618826.16, Epsilon: 0.56
# Episode 116/1000 - Total Reward: 39309324.54, Epsilon: 0.56
# Episode 117/1000 - Total Reward: 40944448.18, Epsilon: 0.55
# Episode 118/1000 - Total Reward: 39802979.93, Epsilon: 0.55
# Episode 119/1000 - Total Reward: 40852503.34, Epsilon: 0.55
# Episode 120/1000 - Total Reward: 41078460.86, Epsilon: 0.55
# Episode 121/1000 - Total Reward: 40784267.10, Epsilon: 0.54
# Episode 122/1000 - Total Reward: 39731488.47, Epsilon: 0.54
# Episode 123/1000 - Total Reward: 41039212.15, Epsilon: 0.54
# Episode 124/1000 - Total Reward: 39809302.34, Epsilon: 0.53
# Episode 125/1000 - Total Reward: 40809810.94, Epsilon: 0.53
# Episode 126/1000 - Total Reward: 40473203.41, Epsilon: 0.53
# Episode 127/1000 - Total Reward: 39878265.64, Epsilon: 0.53
# Episode 128/1000 - Total Reward: 41182890.93, Epsilon: 0.52
# Episode 129/1000 - Total Reward: 39906153.55, Epsilon: 0.52
# Episode 130/1000 - Total Reward: 40435436.70, Epsilon: 0.52
# Episode 131/1000 - Total Reward: 39784947.74, Epsilon: 0.52
# Episode 132/1000 - Total Reward: 39852056.24, Epsilon: 0.51
# Episode 133/1000 - Total Reward: 39333745.54, Epsilon: 0.51
# Episode 134/1000 - Total Reward: 39978942.00, Epsilon: 0.51
# Episode 135/1000 - Total Reward: 40050345.25, Epsilon: 0.51
# Episode 136/1000 - Total Reward: 41450079.16, Epsilon: 0.50
# Episode 137/1000 - Total Reward: 40002374.52, Epsilon: 0.50
# Episode 138/1000 - Total Reward: 40138968.52, Epsilon: 0.50
# Episode 139/1000 - Total Reward: 39966432.42, Epsilon: 0.50
# Episode 140/1000 - Total Reward: 40064970.45, Epsilon: 0.49
# Episode 141/1000 - Total Reward: 40156872.90, Epsilon: 0.49
# Episode 142/1000 - Total Reward: 40758666.01, Epsilon: 0.49
# Episode 143/1000 - Total Reward: 41824308.36, Epsilon: 0.49
# Episode 144/1000 - Total Reward: 41713142.48, Epsilon: 0.48
# Episode 145/1000 - Total Reward: 39678329.13, Epsilon: 0.48
# Episode 146/1000 - Total Reward: 42769623.54, Epsilon: 0.48
# Episode 147/1000 - Total Reward: 40989744.40, Epsilon: 0.48
# Episode 148/1000 - Total Reward: 40509585.40, Epsilon: 0.47
# Episode 149/1000 - Total Reward: 40480786.81, Epsilon: 0.47
# Episode 150/1000 - Total Reward: 40572541.20, Epsilon: 0.47
# Episode 151/1000 - Total Reward: 40938102.45, Epsilon: 0.47
# Episode 152/1000 - Total Reward: 41140887.22, Epsilon: 0.46
# Episode 153/1000 - Total Reward: 41206241.07, Epsilon: 0.46
# Episode 154/1000 - Total Reward: 41070967.55, Epsilon: 0.46
# Episode 155/1000 - Total Reward: 40165010.45, Epsilon: 0.46
# Episode 156/1000 - Total Reward: 39929932.78, Epsilon: 0.46
# Episode 157/1000 - Total Reward: 41590573.69, Epsilon: 0.45
# Episode 158/1000 - Total Reward: 40853581.19, Epsilon: 0.45
# Episode 159/1000 - Total Reward: 40961593.97, Epsilon: 0.45
# Episode 160/1000 - Total Reward: 41058447.91, Epsilon: 0.45
# Episode 161/1000 - Total Reward: 40807911.62, Epsilon: 0.44
# Episode 162/1000 - Total Reward: 41066241.49, Epsilon: 0.44
# Episode 163/1000 - Total Reward: 40662101.94, Epsilon: 0.44
# Episode 164/1000 - Total Reward: 40984473.34, Epsilon: 0.44
# Episode 165/1000 - Total Reward: 41513766.39, Epsilon: 0.44
# Episode 166/1000 - Total Reward: 40040581.82, Epsilon: 0.43
# Episode 167/1000 - Total Reward: 39918111.19, Epsilon: 0.43
# Episode 168/1000 - Total Reward: 39683285.69, Epsilon: 0.43
# Episode 169/1000 - Total Reward: 40947478.33, Epsilon: 0.43
# Episode 170/1000 - Total Reward: 41133707.77, Epsilon: 0.42
# Episode 171/1000 - Total Reward: 39603026.71, Epsilon: 0.42
# Episode 172/1000 - Total Reward: 39781128.91, Epsilon: 0.42
# Episode 173/1000 - Total Reward: 41282565.81, Epsilon: 0.42
# Episode 174/1000 - Total Reward: 40611309.93, Epsilon: 0.42
# Episode 175/1000 - Total Reward: 41900901.96, Epsilon: 0.41
# Episode 176/1000 - Total Reward: 40788860.29, Epsilon: 0.41
# Episode 177/1000 - Total Reward: 40504385.16, Epsilon: 0.41
# Episode 178/1000 - Total Reward: 40845228.23, Epsilon: 0.41
# Episode 179/1000 - Total Reward: 40058171.04, Epsilon: 0.41
# Episode 180/1000 - Total Reward: 40927643.88, Epsilon: 0.40
# Episode 181/1000 - Total Reward: 41048062.48, Epsilon: 0.40
# Episode 182/1000 - Total Reward: 41065257.68, Epsilon: 0.40
# Episode 183/1000 - Total Reward: 40758412.11, Epsilon: 0.40
# Episode 184/1000 - Total Reward: 41341189.23, Epsilon: 0.40
# Episode 185/1000 - Total Reward: 41011162.08, Epsilon: 0.39
# Episode 186/1000 - Total Reward: 41555382.84, Epsilon: 0.39
# Episode 187/1000 - Total Reward: 40900647.51, Epsilon: 0.39
# Episode 188/1000 - Total Reward: 40352837.90, Epsilon: 0.39
# Episode 189/1000 - Total Reward: 40185895.76, Epsilon: 0.39
# Episode 190/1000 - Total Reward: 41413568.81, Epsilon: 0.38
# Episode 191/1000 - Total Reward: 40991267.01, Epsilon: 0.38
# Episode 192/1000 - Total Reward: 40905327.35, Epsilon: 0.38
# Episode 193/1000 - Total Reward: 41152582.96, Epsilon: 0.38
# Episode 194/1000 - Total Reward: 40847837.55, Epsilon: 0.38
# Episode 195/1000 - Total Reward: 41163009.63, Epsilon: 0.37
# Episode 196/1000 - Total Reward: 40594302.59, Epsilon: 0.37
# Episode 197/1000 - Total Reward: 40215024.71, Epsilon: 0.37
# Episode 198/1000 - Total Reward: 40488674.15, Epsilon: 0.37
# Episode 199/1000 - Total Reward: 41014846.02, Epsilon: 0.37
# Episode 200/1000 - Total Reward: 41233595.59, Epsilon: 0.37
# Episode 201/1000 - Total Reward: 40461962.23, Epsilon: 0.36
# Episode 202/1000 - Total Reward: 41686440.75, Epsilon: 0.36
# Episode 203/1000 - Total Reward: 40777072.82, Epsilon: 0.36
# Episode 204/1000 - Total Reward: 40705189.50, Epsilon: 0.36
# Episode 205/1000 - Total Reward: 40440402.74, Epsilon: 0.36
# Episode 206/1000 - Total Reward: 41479855.33, Epsilon: 0.35
# Episode 207/1000 - Total Reward: 41703826.89, Epsilon: 0.35
# Episode 208/1000 - Total Reward: 40397742.80, Epsilon: 0.35
# Episode 209/1000 - Total Reward: 40385378.11, Epsilon: 0.35
# Episode 210/1000 - Total Reward: 41338303.62, Epsilon: 0.35
# Episode 211/1000 - Total Reward: 40625347.38, Epsilon: 0.35
# Episode 212/1000 - Total Reward: 40600921.31, Epsilon: 0.34
# Episode 213/1000 - Total Reward: 40739338.96, Epsilon: 0.34
# Episode 214/1000 - Total Reward: 41302113.24, Epsilon: 0.34
# Episode 215/1000 - Total Reward: 41684214.90, Epsilon: 0.34
# Episode 216/1000 - Total Reward: 40603621.02, Epsilon: 0.34
# Episode 217/1000 - Total Reward: 41487838.41, Epsilon: 0.34
# Episode 218/1000 - Total Reward: 41446886.62, Epsilon: 0.33
# Episode 219/1000 - Total Reward: 41310520.41, Epsilon: 0.33
# Episode 220/1000 - Total Reward: 40938202.61, Epsilon: 0.33
# Episode 221/1000 - Total Reward: 40836383.84, Epsilon: 0.33
# Episode 222/1000 - Total Reward: 41898075.76, Epsilon: 0.33
# Episode 223/1000 - Total Reward: 41147951.58, Epsilon: 0.33
# Episode 224/1000 - Total Reward: 40796808.10, Epsilon: 0.32
# Episode 225/1000 - Total Reward: 41180548.57, Epsilon: 0.32
# Episode 226/1000 - Total Reward: 41187471.66, Epsilon: 0.32
# Episode 227/1000 - Total Reward: 40234748.97, Epsilon: 0.32
# Episode 228/1000 - Total Reward: 41216557.51, Epsilon: 0.32
# Episode 229/1000 - Total Reward: 41330274.68, Epsilon: 0.32
# Episode 230/1000 - Total Reward: 40338253.49, Epsilon: 0.31
# Episode 231/1000 - Total Reward: 42340792.49, Epsilon: 0.31
# Episode 232/1000 - Total Reward: 41054883.79, Epsilon: 0.31
# Episode 233/1000 - Total Reward: 41746128.93, Epsilon: 0.31
# Episode 234/1000 - Total Reward: 41248962.01, Epsilon: 0.31
# Episode 235/1000 - Total Reward: 41454365.46, Epsilon: 0.31
# Episode 236/1000 - Total Reward: 42376243.95, Epsilon: 0.30
# Episode 237/1000 - Total Reward: 41581537.01, Epsilon: 0.30
# Episode 238/1000 - Total Reward: 40592884.71, Epsilon: 0.30
# Episode 239/1000 - Total Reward: 40502348.13, Epsilon: 0.30
# Episode 240/1000 - Total Reward: 40922205.64, Epsilon: 0.30
# Episode 241/1000 - Total Reward: 41991565.10, Epsilon: 0.30
# Episode 242/1000 - Total Reward: 41154527.17, Epsilon: 0.30
# Episode 243/1000 - Total Reward: 41085960.59, Epsilon: 0.29
# Episode 244/1000 - Total Reward: 40756264.05, Epsilon: 0.29
# Episode 245/1000 - Total Reward: 41280824.51, Epsilon: 0.29
# Episode 246/1000 - Total Reward: 41383572.57, Epsilon: 0.29
# Episode 247/1000 - Total Reward: 41000883.05, Epsilon: 0.29
# Episode 248/1000 - Total Reward: 41519957.08, Epsilon: 0.29
# Episode 249/1000 - Total Reward: 41269361.41, Epsilon: 0.29
# Episode 250/1000 - Total Reward: 42321183.11, Epsilon: 0.28
# Episode 251/1000 - Total Reward: 40695473.05, Epsilon: 0.28
# Episode 252/1000 - Total Reward: 40791815.91, Epsilon: 0.28
# Episode 253/1000 - Total Reward: 41178442.33, Epsilon: 0.28
# Episode 254/1000 - Total Reward: 41591766.81, Epsilon: 0.28
# Episode 255/1000 - Total Reward: 41373068.77, Epsilon: 0.28
# Episode 256/1000 - Total Reward: 41133403.29, Epsilon: 0.28
# Episode 257/1000 - Total Reward: 40965254.85, Epsilon: 0.27
# Episode 258/1000 - Total Reward: 41319838.53, Epsilon: 0.27
# Episode 259/1000 - Total Reward: 41763038.63, Epsilon: 0.27
# Episode 260/1000 - Total Reward: 41499890.54, Epsilon: 0.27
# Episode 261/1000 - Total Reward: 41244784.87, Epsilon: 0.27
# Episode 262/1000 - Total Reward: 41796434.81, Epsilon: 0.27
# Episode 263/1000 - Total Reward: 41394731.72, Epsilon: 0.27
# Episode 264/1000 - Total Reward: 41563205.23, Epsilon: 0.26
# Episode 265/1000 - Total Reward: 40849087.85, Epsilon: 0.26
# Episode 266/1000 - Total Reward: 41669793.67, Epsilon: 0.26
# Episode 267/1000 - Total Reward: 40117342.25, Epsilon: 0.26
# Episode 268/1000 - Total Reward: 41075224.54, Epsilon: 0.26
# Episode 269/1000 - Total Reward: 40885952.46, Epsilon: 0.26
# Episode 270/1000 - Total Reward: 41861327.59, Epsilon: 0.26
# Episode 271/1000 - Total Reward: 41182193.49, Epsilon: 0.26
# Episode 272/1000 - Total Reward: 40776972.57, Epsilon: 0.25
# Episode 273/1000 - Total Reward: 41102184.47, Epsilon: 0.25
# Episode 274/1000 - Total Reward: 41222451.46, Epsilon: 0.25
# Episode 275/1000 - Total Reward: 41573039.35, Epsilon: 0.25
# Episode 276/1000 - Total Reward: 40542287.47, Epsilon: 0.25
# Episode 277/1000 - Total Reward: 41519822.48, Epsilon: 0.25
# Episode 278/1000 - Total Reward: 40973416.95, Epsilon: 0.25
# Episode 279/1000 - Total Reward: 41308943.41, Epsilon: 0.25
# Episode 280/1000 - Total Reward: 40896228.68, Epsilon: 0.24
# Episode 281/1000 - Total Reward: 41247539.58, Epsilon: 0.24
# Episode 282/1000 - Total Reward: 41678403.91, Epsilon: 0.24
# Episode 283/1000 - Total Reward: 41091483.76, Epsilon: 0.24
# Episode 284/1000 - Total Reward: 41006854.58, Epsilon: 0.24
# Episode 285/1000 - Total Reward: 41109926.60, Epsilon: 0.24
# Episode 286/1000 - Total Reward: 40986655.10, Epsilon: 0.24
# Episode 287/1000 - Total Reward: 41273900.91, Epsilon: 0.24
# Episode 288/1000 - Total Reward: 41319507.69, Epsilon: 0.23
# Episode 289/1000 - Total Reward: 41822357.52, Epsilon: 0.23
# Episode 290/1000 - Total Reward: 41239421.55, Epsilon: 0.23
# Episode 291/1000 - Total Reward: 41943052.18, Epsilon: 0.23
# Episode 292/1000 - Total Reward: 41410754.41, Epsilon: 0.23
# Episode 293/1000 - Total Reward: 40792563.18, Epsilon: 0.23
# Episode 294/1000 - Total Reward: 40736394.74, Epsilon: 0.23
# Episode 295/1000 - Total Reward: 42105890.73, Epsilon: 0.23
# Episode 296/1000 - Total Reward: 41775958.47, Epsilon: 0.23
# Episode 297/1000 - Total Reward: 42413131.06, Epsilon: 0.22
# Episode 298/1000 - Total Reward: 41613674.78, Epsilon: 0.22
# Episode 299/1000 - Total Reward: 41322283.15, Epsilon: 0.22
# Episode 300/1000 - Total Reward: 40658208.71, Epsilon: 0.22
# Episode 301/1000 - Total Reward: 41131957.26, Epsilon: 0.22
# Episode 302/1000 - Total Reward: 41676235.67, Epsilon: 0.22
# Episode 303/1000 - Total Reward: 41415948.23, Epsilon: 0.22
# Episode 304/1000 - Total Reward: 41571040.21, Epsilon: 0.22
# Episode 305/1000 - Total Reward: 42204953.07, Epsilon: 0.22
# Episode 306/1000 - Total Reward: 41417306.49, Epsilon: 0.21
# Episode 307/1000 - Total Reward: 41605416.77, Epsilon: 0.21
# Episode 308/1000 - Total Reward: 42078080.00, Epsilon: 0.21
# Episode 309/1000 - Total Reward: 41735885.60, Epsilon: 0.21
# Episode 310/1000 - Total Reward: 41425914.89, Epsilon: 0.21
# Episode 311/1000 - Total Reward: 42209762.48, Epsilon: 0.21
# Episode 312/1000 - Total Reward: 41509723.95, Epsilon: 0.21
# Episode 313/1000 - Total Reward: 41737981.55, Epsilon: 0.21
# Episode 314/1000 - Total Reward: 40882609.28, Epsilon: 0.21
# Episode 315/1000 - Total Reward: 40914448.52, Epsilon: 0.21
# Episode 316/1000 - Total Reward: 41573531.23, Epsilon: 0.20
# Episode 317/1000 - Total Reward: 41448182.61, Epsilon: 0.20
# Episode 318/1000 - Total Reward: 41462025.51, Epsilon: 0.20
# Episode 319/1000 - Total Reward: 42050282.99, Epsilon: 0.20
# Episode 320/1000 - Total Reward: 41087317.82, Epsilon: 0.20
# Episode 321/1000 - Total Reward: 41243347.17, Epsilon: 0.20
# Episode 322/1000 - Total Reward: 41177748.82, Epsilon: 0.20
# Episode 323/1000 - Total Reward: 41450670.93, Epsilon: 0.20
# Episode 324/1000 - Total Reward: 40691846.40, Epsilon: 0.20
# Episode 325/1000 - Total Reward: 41870794.24, Epsilon: 0.20
# Episode 326/1000 - Total Reward: 41245378.18, Epsilon: 0.19
# Episode 327/1000 - Total Reward: 42015133.48, Epsilon: 0.19
# Episode 328/1000 - Total Reward: 41981653.58, Epsilon: 0.19
# Episode 329/1000 - Total Reward: 41774179.30, Epsilon: 0.19
# Episode 330/1000 - Total Reward: 41773194.91, Epsilon: 0.19
# Episode 331/1000 - Total Reward: 41680666.77, Epsilon: 0.19
# Episode 332/1000 - Total Reward: 42180580.13, Epsilon: 0.19
# Episode 333/1000 - Total Reward: 41384983.61, Epsilon: 0.19
# Episode 334/1000 - Total Reward: 41477436.84, Epsilon: 0.19
# Episode 335/1000 - Total Reward: 42078361.87, Epsilon: 0.19
# Episode 336/1000 - Total Reward: 40688249.04, Epsilon: 0.18
# Episode 337/1000 - Total Reward: 41070162.46, Epsilon: 0.18
# Episode 338/1000 - Total Reward: 41324775.78, Epsilon: 0.18
# Episode 339/1000 - Total Reward: 41386615.87, Epsilon: 0.18
# Episode 340/1000 - Total Reward: 41995116.67, Epsilon: 0.18
# Episode 341/1000 - Total Reward: 41621321.63, Epsilon: 0.18
# Episode 342/1000 - Total Reward: 41574429.35, Epsilon: 0.18
# Episode 343/1000 - Total Reward: 41077185.42, Epsilon: 0.18
# Episode 344/1000 - Total Reward: 41827001.55, Epsilon: 0.18
# Episode 345/1000 - Total Reward: 41470668.82, Epsilon: 0.18
# Episode 346/1000 - Total Reward: 41255679.41, Epsilon: 0.18
# Episode 347/1000 - Total Reward: 41855495.05, Epsilon: 0.17
# Episode 348/1000 - Total Reward: 42109601.85, Epsilon: 0.17
# Episode 349/1000 - Total Reward: 41673601.19, Epsilon: 0.17
# Episode 350/1000 - Total Reward: 41361369.46, Epsilon: 0.17
# Episode 351/1000 - Total Reward: 41679690.32, Epsilon: 0.17
# Episode 352/1000 - Total Reward: 41476517.97, Epsilon: 0.17
# Episode 353/1000 - Total Reward: 42255622.70, Epsilon: 0.17
# Episode 354/1000 - Total Reward: 41631270.75, Epsilon: 0.17
# Episode 355/1000 - Total Reward: 41616063.25, Epsilon: 0.17
# Episode 356/1000 - Total Reward: 41519597.70, Epsilon: 0.17
# Episode 357/1000 - Total Reward: 41039968.74, Epsilon: 0.17
# Episode 358/1000 - Total Reward: 41940261.29, Epsilon: 0.17
# Episode 359/1000 - Total Reward: 41816430.64, Epsilon: 0.16
# Episode 360/1000 - Total Reward: 41449396.56, Epsilon: 0.16
# Episode 361/1000 - Total Reward: 41388498.09, Epsilon: 0.16
# Episode 362/1000 - Total Reward: 41263489.39, Epsilon: 0.16
# Episode 363/1000 - Total Reward: 41699742.97, Epsilon: 0.16
# Episode 364/1000 - Total Reward: 41328237.81, Epsilon: 0.16
# Episode 365/1000 - Total Reward: 41093681.21, Epsilon: 0.16
# Episode 366/1000 - Total Reward: 41266828.91, Epsilon: 0.16
# Episode 367/1000 - Total Reward: 41729818.51, Epsilon: 0.16
# Episode 368/1000 - Total Reward: 41964746.44, Epsilon: 0.16
# Episode 369/1000 - Total Reward: 41585981.91, Epsilon: 0.16
# Episode 370/1000 - Total Reward: 41949896.91, Epsilon: 0.16
# Episode 371/1000 - Total Reward: 41086761.64, Epsilon: 0.15
# Episode 372/1000 - Total Reward: 41724853.89, Epsilon: 0.15
# Episode 373/1000 - Total Reward: 41991792.22, Epsilon: 0.15
# Episode 374/1000 - Total Reward: 41647421.11, Epsilon: 0.15
# Episode 375/1000 - Total Reward: 42115217.83, Epsilon: 0.15
# Episode 376/1000 - Total Reward: 42265245.60, Epsilon: 0.15
# Episode 377/1000 - Total Reward: 41780688.00, Epsilon: 0.15
# Episode 378/1000 - Total Reward: 41512091.59, Epsilon: 0.15
# Episode 379/1000 - Total Reward: 42446288.34, Epsilon: 0.15
# Episode 380/1000 - Total Reward: 41643755.43, Epsilon: 0.15
# Episode 381/1000 - Total Reward: 41876476.34, Epsilon: 0.15
# Episode 382/1000 - Total Reward: 41861873.46, Epsilon: 0.15
# Episode 383/1000 - Total Reward: 41652590.04, Epsilon: 0.15
# Episode 384/1000 - Total Reward: 40596504.25, Epsilon: 0.15
# Episode 385/1000 - Total Reward: 41921335.57, Epsilon: 0.14
# Episode 386/1000 - Total Reward: 41686151.76, Epsilon: 0.14
# Episode 387/1000 - Total Reward: 40896387.01, Epsilon: 0.14
# Episode 388/1000 - Total Reward: 41642655.42, Epsilon: 0.14
# Episode 389/1000 - Total Reward: 41397017.00, Epsilon: 0.14
# Episode 390/1000 - Total Reward: 41474814.09, Epsilon: 0.14
# Episode 391/1000 - Total Reward: 41488515.84, Epsilon: 0.14
# Episode 392/1000 - Total Reward: 41949798.17, Epsilon: 0.14
# Episode 393/1000 - Total Reward: 40864824.65, Epsilon: 0.14
# Episode 394/1000 - Total Reward: 41692983.77, Epsilon: 0.14
# Episode 395/1000 - Total Reward: 41698117.64, Epsilon: 0.14
# Episode 396/1000 - Total Reward: 41530196.35, Epsilon: 0.14
# Episode 397/1000 - Total Reward: 42034970.09, Epsilon: 0.14
# Episode 398/1000 - Total Reward: 41691768.42, Epsilon: 0.14
# Episode 399/1000 - Total Reward: 41582540.86, Epsilon: 0.13
# Episode 400/1000 - Total Reward: 42088508.18, Epsilon: 0.13
# Episode 401/1000 - Total Reward: 42072001.76, Epsilon: 0.13
# Episode 402/1000 - Total Reward: 41649267.08, Epsilon: 0.13
# Episode 403/1000 - Total Reward: 41274631.40, Epsilon: 0.13
# Episode 404/1000 - Total Reward: 42194120.91, Epsilon: 0.13
# Episode 405/1000 - Total Reward: 42092172.93, Epsilon: 0.13
# Episode 406/1000 - Total Reward: 41133848.26, Epsilon: 0.13
# Episode 407/1000 - Total Reward: 40878224.81, Epsilon: 0.13
# Episode 408/1000 - Total Reward: 41178492.50, Epsilon: 0.13
# Episode 409/1000 - Total Reward: 41451484.48, Epsilon: 0.13
# Episode 410/1000 - Total Reward: 41953126.69, Epsilon: 0.13
# Episode 411/1000 - Total Reward: 41474188.12, Epsilon: 0.13
# Episode 412/1000 - Total Reward: 41532091.89, Epsilon: 0.13
# Episode 413/1000 - Total Reward: 41788974.61, Epsilon: 0.13
# Episode 414/1000 - Total Reward: 41692652.39, Epsilon: 0.12
# Episode 415/1000 - Total Reward: 41115430.29, Epsilon: 0.12
# Episode 416/1000 - Total Reward: 41321618.17, Epsilon: 0.12
# Episode 417/1000 - Total Reward: 41944278.78, Epsilon: 0.12
# Episode 418/1000 - Total Reward: 41457538.82, Epsilon: 0.12
# Episode 419/1000 - Total Reward: 41759666.65, Epsilon: 0.12
# Episode 420/1000 - Total Reward: 41923605.18, Epsilon: 0.12
# Episode 421/1000 - Total Reward: 41782735.51, Epsilon: 0.12
# Episode 422/1000 - Total Reward: 42713912.07, Epsilon: 0.12
# Episode 423/1000 - Total Reward: 41802654.88, Epsilon: 0.12
# Episode 424/1000 - Total Reward: 41882798.58, Epsilon: 0.12
# Episode 425/1000 - Total Reward: 40894751.82, Epsilon: 0.12
# Episode 426/1000 - Total Reward: 41646112.39, Epsilon: 0.12
# Episode 427/1000 - Total Reward: 41570290.46, Epsilon: 0.12
# Episode 428/1000 - Total Reward: 41829655.27, Epsilon: 0.12
# Episode 429/1000 - Total Reward: 41432122.86, Epsilon: 0.12
# Episode 430/1000 - Total Reward: 41311641.75, Epsilon: 0.12
# Episode 431/1000 - Total Reward: 41847537.77, Epsilon: 0.11
# Episode 432/1000 - Total Reward: 41558215.54, Epsilon: 0.11
# Episode 433/1000 - Total Reward: 41900191.67, Epsilon: 0.11
# Episode 434/1000 - Total Reward: 41836088.13, Epsilon: 0.11
# Episode 435/1000 - Total Reward: 41512710.10, Epsilon: 0.11
# Episode 436/1000 - Total Reward: 42058266.49, Epsilon: 0.11
# Episode 437/1000 - Total Reward: 42190793.46, Epsilon: 0.11
# Episode 438/1000 - Total Reward: 41390599.59, Epsilon: 0.11
# Episode 439/1000 - Total Reward: 42036253.72, Epsilon: 0.11
# Episode 440/1000 - Total Reward: 41696043.27, Epsilon: 0.11
# Episode 441/1000 - Total Reward: 41820957.87, Epsilon: 0.11
# Episode 442/1000 - Total Reward: 41624755.87, Epsilon: 0.11
# Episode 443/1000 - Total Reward: 41652915.36, Epsilon: 0.11
# Episode 444/1000 - Total Reward: 41615899.95, Epsilon: 0.11
# Episode 445/1000 - Total Reward: 42302664.18, Epsilon: 0.11
# Episode 446/1000 - Total Reward: 41547598.58, Epsilon: 0.11
# Episode 447/1000 - Total Reward: 41724886.40, Epsilon: 0.11
# Episode 448/1000 - Total Reward: 41819192.48, Epsilon: 0.11
# Episode 449/1000 - Total Reward: 42001129.92, Epsilon: 0.10
# Episode 450/1000 - Total Reward: 42286411.19, Epsilon: 0.10
# Episode 451/1000 - Total Reward: 40976181.06, Epsilon: 0.10
# Episode 452/1000 - Total Reward: 41239684.04, Epsilon: 0.10
# Episode 453/1000 - Total Reward: 41929079.48, Epsilon: 0.10
# Episode 454/1000 - Total Reward: 41870701.66, Epsilon: 0.10
# Episode 455/1000 - Total Reward: 41869985.11, Epsilon: 0.10
# Episode 456/1000 - Total Reward: 40681715.81, Epsilon: 0.10
# Episode 457/1000 - Total Reward: 41986393.20, Epsilon: 0.10
# Episode 458/1000 - Total Reward: 41422892.59, Epsilon: 0.10
# Episode 459/1000 - Total Reward: 41606828.41, Epsilon: 0.10
# Episode 460/1000 - Total Reward: 42263793.96, Epsilon: 0.10
# Episode 461/1000 - Total Reward: 41442807.89, Epsilon: 0.10
# Episode 462/1000 - Total Reward: 41585128.55, Epsilon: 0.10
# Episode 463/1000 - Total Reward: 41764469.90, Epsilon: 0.10
# Episode 464/1000 - Total Reward: 41893742.76, Epsilon: 0.10
# Episode 465/1000 - Total Reward: 41882197.38, Epsilon: 0.10
# Episode 466/1000 - Total Reward: 41601693.29, Epsilon: 0.10
# Episode 467/1000 - Total Reward: 41822347.90, Epsilon: 0.10
# Episode 468/1000 - Total Reward: 41083725.58, Epsilon: 0.10
# Episode 469/1000 - Total Reward: 41744709.89, Epsilon: 0.09
# Episode 470/1000 - Total Reward: 41661583.33, Epsilon: 0.09
# Episode 471/1000 - Total Reward: 41408284.26, Epsilon: 0.09
# Episode 472/1000 - Total Reward: 42160673.28, Epsilon: 0.09
# Episode 473/1000 - Total Reward: 41602448.78, Epsilon: 0.09
# Episode 474/1000 - Total Reward: 42036362.81, Epsilon: 0.09
# Episode 475/1000 - Total Reward: 41432460.61, Epsilon: 0.09
# Episode 476/1000 - Total Reward: 41741194.63, Epsilon: 0.09
# Episode 477/1000 - Total Reward: 41312438.02, Epsilon: 0.09
# Episode 478/1000 - Total Reward: 42363430.30, Epsilon: 0.09
# Episode 479/1000 - Total Reward: 41740402.68, Epsilon: 0.09
# Episode 480/1000 - Total Reward: 41833950.67, Epsilon: 0.09
# Episode 481/1000 - Total Reward: 41949132.29, Epsilon: 0.09
# Episode 482/1000 - Total Reward: 41777316.80, Epsilon: 0.09
# Episode 483/1000 - Total Reward: 41727687.67, Epsilon: 0.09
# Episode 484/1000 - Total Reward: 41286346.84, Epsilon: 0.09
# Episode 485/1000 - Total Reward: 41578486.65, Epsilon: 0.09
# Episode 486/1000 - Total Reward: 41836373.81, Epsilon: 0.09
# Episode 487/1000 - Total Reward: 41708299.92, Epsilon: 0.09
# Episode 488/1000 - Total Reward: 41943922.21, Epsilon: 0.09
# Episode 489/1000 - Total Reward: 41912321.79, Epsilon: 0.09
# Episode 490/1000 - Total Reward: 42039323.25, Epsilon: 0.09
# Episode 491/1000 - Total Reward: 41486634.11, Epsilon: 0.08
# Episode 492/1000 - Total Reward: 41438274.22, Epsilon: 0.08
# Episode 493/1000 - Total Reward: 42111930.21, Epsilon: 0.08
# Episode 494/1000 - Total Reward: 42109312.31, Epsilon: 0.08
# Episode 495/1000 - Total Reward: 41901197.40, Epsilon: 0.08
# Episode 496/1000 - Total Reward: 41311018.31, Epsilon: 0.08
# Episode 497/1000 - Total Reward: 41829783.99, Epsilon: 0.08
# Episode 498/1000 - Total Reward: 41763881.91, Epsilon: 0.08
# Episode 499/1000 - Total Reward: 42091856.48, Epsilon: 0.08
# Episode 500/1000 - Total Reward: 41601751.18, Epsilon: 0.08
# Episode 501/1000 - Total Reward: 41932620.47, Epsilon: 0.08
# Episode 502/1000 - Total Reward: 41734869.04, Epsilon: 0.08
# Episode 503/1000 - Total Reward: 41692344.59, Epsilon: 0.08
# Episode 504/1000 - Total Reward: 41703925.72, Epsilon: 0.08
# Episode 505/1000 - Total Reward: 41773583.03, Epsilon: 0.08
# Episode 506/1000 - Total Reward: 41828478.79, Epsilon: 0.08
# Episode 507/1000 - Total Reward: 41939931.15, Epsilon: 0.08
# Episode 508/1000 - Total Reward: 41838373.12, Epsilon: 0.08
# Episode 509/1000 - Total Reward: 41789553.90, Epsilon: 0.08
# Episode 510/1000 - Total Reward: 41919343.34, Epsilon: 0.08
# Episode 511/1000 - Total Reward: 41657072.30, Epsilon: 0.08
# Episode 512/1000 - Total Reward: 42105117.97, Epsilon: 0.08
# Episode 513/1000 - Total Reward: 42189955.62, Epsilon: 0.08
# Episode 514/1000 - Total Reward: 42099202.36, Epsilon: 0.08
# Episode 515/1000 - Total Reward: 41602250.53, Epsilon: 0.08
# Episode 516/1000 - Total Reward: 41712789.63, Epsilon: 0.07
# Episode 517/1000 - Total Reward: 42010956.03, Epsilon: 0.07
# Episode 518/1000 - Total Reward: 41854346.65, Epsilon: 0.07
# Episode 519/1000 - Total Reward: 42036897.57, Epsilon: 0.07
# Episode 520/1000 - Total Reward: 41602591.02, Epsilon: 0.07
# Episode 521/1000 - Total Reward: 41808794.32, Epsilon: 0.07
# Episode 522/1000 - Total Reward: 42090428.48, Epsilon: 0.07
# Episode 523/1000 - Total Reward: 41826422.51, Epsilon: 0.07
# Episode 524/1000 - Total Reward: 41879252.90, Epsilon: 0.07
# Episode 525/1000 - Total Reward: 41812717.82, Epsilon: 0.07
# Episode 526/1000 - Total Reward: 41844531.69, Epsilon: 0.07
# Episode 527/1000 - Total Reward: 41874720.36, Epsilon: 0.07
# Episode 528/1000 - Total Reward: 41883742.27, Epsilon: 0.07
# Episode 529/1000 - Total Reward: 41520151.41, Epsilon: 0.07
# Episode 530/1000 - Total Reward: 41937877.90, Epsilon: 0.07
# Episode 531/1000 - Total Reward: 42322770.04, Epsilon: 0.07
# Episode 532/1000 - Total Reward: 41830630.49, Epsilon: 0.07
# Episode 533/1000 - Total Reward: 42137184.10, Epsilon: 0.07
# Episode 534/1000 - Total Reward: 41849230.57, Epsilon: 0.07
# Episode 535/1000 - Total Reward: 41675412.63, Epsilon: 0.07
# Episode 536/1000 - Total Reward: 42157090.83, Epsilon: 0.07
# Episode 537/1000 - Total Reward: 41923267.23, Epsilon: 0.07
# Episode 538/1000 - Total Reward: 42253221.21, Epsilon: 0.07
# Episode 539/1000 - Total Reward: 42033770.35, Epsilon: 0.07
# Episode 540/1000 - Total Reward: 42040346.57, Epsilon: 0.07
# Episode 541/1000 - Total Reward: 41945628.87, Epsilon: 0.07
# Episode 542/1000 - Total Reward: 41687470.62, Epsilon: 0.07
# Episode 543/1000 - Total Reward: 41928196.48, Epsilon: 0.07
# Episode 544/1000 - Total Reward: 41585273.63, Epsilon: 0.07
# Episode 545/1000 - Total Reward: 41818900.45, Epsilon: 0.06
# Episode 546/1000 - Total Reward: 41855349.04, Epsilon: 0.06
# Episode 547/1000 - Total Reward: 41928746.07, Epsilon: 0.06
# Episode 548/1000 - Total Reward: 41994934.73, Epsilon: 0.06
# Episode 549/1000 - Total Reward: 41928981.84, Epsilon: 0.06
# Episode 550/1000 - Total Reward: 42118796.40, Epsilon: 0.06
# Episode 551/1000 - Total Reward: 41818346.18, Epsilon: 0.06
# Episode 552/1000 - Total Reward: 41744303.19, Epsilon: 0.06
# Episode 553/1000 - Total Reward: 42333182.10, Epsilon: 0.06
# Episode 554/1000 - Total Reward: 41723229.64, Epsilon: 0.06
# Episode 555/1000 - Total Reward: 41824822.21, Epsilon: 0.06
# Episode 556/1000 - Total Reward: 42112920.88, Epsilon: 0.06
# Episode 557/1000 - Total Reward: 42341535.36, Epsilon: 0.06
# Episode 558/1000 - Total Reward: 42180836.45, Epsilon: 0.06
# Episode 559/1000 - Total Reward: 41612897.15, Epsilon: 0.06
# Episode 560/1000 - Total Reward: 41944535.76, Epsilon: 0.06
# Episode 561/1000 - Total Reward: 41842356.67, Epsilon: 0.06
# Episode 562/1000 - Total Reward: 42275750.29, Epsilon: 0.06
# Episode 563/1000 - Total Reward: 41974103.94, Epsilon: 0.06
# Episode 564/1000 - Total Reward: 41981264.57, Epsilon: 0.06
# Episode 565/1000 - Total Reward: 41292083.22, Epsilon: 0.06
# Episode 566/1000 - Total Reward: 41934819.01, Epsilon: 0.06
# Episode 567/1000 - Total Reward: 41570106.99, Epsilon: 0.06
# Episode 568/1000 - Total Reward: 41787981.58, Epsilon: 0.06
# Episode 569/1000 - Total Reward: 41913261.58, Epsilon: 0.06
# Episode 570/1000 - Total Reward: 41858255.01, Epsilon: 0.06
# Episode 571/1000 - Total Reward: 41700375.32, Epsilon: 0.06
# Episode 572/1000 - Total Reward: 41989653.87, Epsilon: 0.06
# Episode 573/1000 - Total Reward: 41783753.35, Epsilon: 0.06
# Episode 574/1000 - Total Reward: 41924589.73, Epsilon: 0.06
# Episode 575/1000 - Total Reward: 42014688.35, Epsilon: 0.06
# Episode 576/1000 - Total Reward: 41814337.94, Epsilon: 0.06
# Episode 577/1000 - Total Reward: 41932874.34, Epsilon: 0.06
# Episode 578/1000 - Total Reward: 42146378.80, Epsilon: 0.05
# Episode 579/1000 - Total Reward: 41787178.67, Epsilon: 0.05
# Episode 580/1000 - Total Reward: 41907757.30, Epsilon: 0.05
# Episode 581/1000 - Total Reward: 41091807.80, Epsilon: 0.05
# Episode 582/1000 - Total Reward: 41955449.21, Epsilon: 0.05
# Episode 583/1000 - Total Reward: 41728548.87, Epsilon: 0.05
# Episode 584/1000 - Total Reward: 42326801.75, Epsilon: 0.05
# Episode 585/1000 - Total Reward: 41847386.66, Epsilon: 0.05
# Episode 586/1000 - Total Reward: 41755345.05, Epsilon: 0.05
# Episode 587/1000 - Total Reward: 41748403.24, Epsilon: 0.05
# Episode 588/1000 - Total Reward: 41784698.07, Epsilon: 0.05
# Episode 589/1000 - Total Reward: 41984840.56, Epsilon: 0.05
# Episode 590/1000 - Total Reward: 41583435.01, Epsilon: 0.05
# Episode 591/1000 - Total Reward: 42142706.66, Epsilon: 0.05
# Episode 592/1000 - Total Reward: 42005899.28, Epsilon: 0.05
# Episode 593/1000 - Total Reward: 41915605.12, Epsilon: 0.05
# Episode 594/1000 - Total Reward: 41985607.70, Epsilon: 0.05
# Episode 595/1000 - Total Reward: 41775745.76, Epsilon: 0.05
# Episode 596/1000 - Total Reward: 41922171.44, Epsilon: 0.05
# Episode 597/1000 - Total Reward: 42019865.16, Epsilon: 0.05
# Episode 598/1000 - Total Reward: 41993524.49, Epsilon: 0.05
# Episode 599/1000 - Total Reward: 41870914.41, Epsilon: 0.05
# Episode 600/1000 - Total Reward: 41889132.77, Epsilon: 0.05
# Episode 601/1000 - Total Reward: 41862787.07, Epsilon: 0.05
# Episode 602/1000 - Total Reward: 41997428.30, Epsilon: 0.05
# Episode 603/1000 - Total Reward: 42082954.12, Epsilon: 0.05
# Episode 604/1000 - Total Reward: 41896063.05, Epsilon: 0.05
# Episode 605/1000 - Total Reward: 42312575.05, Epsilon: 0.05
# Episode 606/1000 - Total Reward: 41967664.29, Epsilon: 0.05
# Episode 607/1000 - Total Reward: 41748815.91, Epsilon: 0.05
# Episode 608/1000 - Total Reward: 41819072.07, Epsilon: 0.05
# Episode 609/1000 - Total Reward: 41857706.54, Epsilon: 0.05
# Episode 610/1000 - Total Reward: 41928121.33, Epsilon: 0.05
# Episode 611/1000 - Total Reward: 42142254.13, Epsilon: 0.05
# Episode 612/1000 - Total Reward: 42024622.31, Epsilon: 0.05
# Episode 613/1000 - Total Reward: 41937003.96, Epsilon: 0.05
# Episode 614/1000 - Total Reward: 41733582.05, Epsilon: 0.05
# Episode 615/1000 - Total Reward: 42013396.92, Epsilon: 0.05
# Episode 616/1000 - Total Reward: 42014420.29, Epsilon: 0.05
# Episode 617/1000 - Total Reward: 41764686.16, Epsilon: 0.05
# Episode 618/1000 - Total Reward: 41930309.45, Epsilon: 0.04
# Episode 619/1000 - Total Reward: 41750712.92, Epsilon: 0.04
# Episode 620/1000 - Total Reward: 41739002.70, Epsilon: 0.04
# Episode 621/1000 - Total Reward: 42039514.39, Epsilon: 0.04
# Episode 622/1000 - Total Reward: 42172925.93, Epsilon: 0.04
# Episode 623/1000 - Total Reward: 42122333.16, Epsilon: 0.04
# Episode 624/1000 - Total Reward: 41730218.71, Epsilon: 0.04
# Episode 625/1000 - Total Reward: 42035865.00, Epsilon: 0.04
# Episode 626/1000 - Total Reward: 42087936.81, Epsilon: 0.04
# Episode 627/1000 - Total Reward: 41886552.21, Epsilon: 0.04
# Episode 628/1000 - Total Reward: 41895363.72, Epsilon: 0.04
# Episode 629/1000 - Total Reward: 42061177.04, Epsilon: 0.04
# Episode 630/1000 - Total Reward: 41978312.74, Epsilon: 0.04
# Episode 631/1000 - Total Reward: 41554795.92, Epsilon: 0.04
# Episode 632/1000 - Total Reward: 41972049.96, Epsilon: 0.04
# Episode 633/1000 - Total Reward: 42080453.98, Epsilon: 0.04
# Episode 634/1000 - Total Reward: 42081960.74, Epsilon: 0.04
# Episode 635/1000 - Total Reward: 41896386.35, Epsilon: 0.04
# Episode 636/1000 - Total Reward: 41541166.94, Epsilon: 0.04
# Episode 637/1000 - Total Reward: 42274739.54, Epsilon: 0.04
# Episode 638/1000 - Total Reward: 42323844.65, Epsilon: 0.04
# Episode 639/1000 - Total Reward: 42024677.12, Epsilon: 0.04
# Episode 640/1000 - Total Reward: 41863271.94, Epsilon: 0.04
# Episode 641/1000 - Total Reward: 42152299.71, Epsilon: 0.04
# Episode 642/1000 - Total Reward: 41700753.95, Epsilon: 0.04
# Episode 643/1000 - Total Reward: 41738028.21, Epsilon: 0.04
# Episode 644/1000 - Total Reward: 41711242.45, Epsilon: 0.04
# Episode 645/1000 - Total Reward: 41902526.27, Epsilon: 0.04
# Episode 646/1000 - Total Reward: 42065585.27, Epsilon: 0.04
# Episode 647/1000 - Total Reward: 42092781.66, Epsilon: 0.04
# Episode 648/1000 - Total Reward: 42230972.26, Epsilon: 0.04
# Episode 649/1000 - Total Reward: 41419015.24, Epsilon: 0.04
# Episode 650/1000 - Total Reward: 41753544.27, Epsilon: 0.04
# Episode 651/1000 - Total Reward: 41672984.67, Epsilon: 0.04
# Episode 652/1000 - Total Reward: 41982432.19, Epsilon: 0.04
# Episode 653/1000 - Total Reward: 41599891.97, Epsilon: 0.04
# Episode 654/1000 - Total Reward: 42055630.71, Epsilon: 0.04
# Episode 655/1000 - Total Reward: 41660182.09, Epsilon: 0.04
# Episode 656/1000 - Total Reward: 41777480.41, Epsilon: 0.04
# Episode 657/1000 - Total Reward: 41937817.65, Epsilon: 0.04
# Episode 658/1000 - Total Reward: 42041815.22, Epsilon: 0.04
# Episode 659/1000 - Total Reward: 42015466.35, Epsilon: 0.04
# Episode 660/1000 - Total Reward: 41578811.45, Epsilon: 0.04
# Episode 661/1000 - Total Reward: 42027160.30, Epsilon: 0.04
# Episode 662/1000 - Total Reward: 42022682.59, Epsilon: 0.04
# Episode 663/1000 - Total Reward: 41764173.24, Epsilon: 0.04
# Episode 664/1000 - Total Reward: 41849421.24, Epsilon: 0.04
# Episode 665/1000 - Total Reward: 41642401.36, Epsilon: 0.04
# Episode 666/1000 - Total Reward: 42084752.25, Epsilon: 0.04
# Episode 667/1000 - Total Reward: 41983606.48, Epsilon: 0.04
# Episode 668/1000 - Total Reward: 42060345.74, Epsilon: 0.03
# Episode 669/1000 - Total Reward: 42200759.85, Epsilon: 0.03
# Episode 670/1000 - Total Reward: 41832038.38, Epsilon: 0.03
# Episode 671/1000 - Total Reward: 42041789.08, Epsilon: 0.03
# Episode 672/1000 - Total Reward: 41714975.22, Epsilon: 0.03
# Episode 673/1000 - Total Reward: 41875414.33, Epsilon: 0.03
# Episode 674/1000 - Total Reward: 41924730.44, Epsilon: 0.03
# Episode 675/1000 - Total Reward: 41817309.36, Epsilon: 0.03
# Episode 676/1000 - Total Reward: 42062814.14, Epsilon: 0.03
# Episode 677/1000 - Total Reward: 41978485.25, Epsilon: 0.03
# Episode 678/1000 - Total Reward: 42016253.51, Epsilon: 0.03
# Episode 679/1000 - Total Reward: 42078666.90, Epsilon: 0.03
# Episode 680/1000 - Total Reward: 41932787.32, Epsilon: 0.03
# Episode 681/1000 - Total Reward: 41864529.50, Epsilon: 0.03
# Episode 682/1000 - Total Reward: 41910082.83, Epsilon: 0.03
# Episode 683/1000 - Total Reward: 41834668.33, Epsilon: 0.03
# Episode 684/1000 - Total Reward: 42116979.04, Epsilon: 0.03
# Episode 685/1000 - Total Reward: 42156094.73, Epsilon: 0.03
# Episode 686/1000 - Total Reward: 42022563.41, Epsilon: 0.03
# Episode 687/1000 - Total Reward: 42042145.09, Epsilon: 0.03
# Episode 688/1000 - Total Reward: 42096615.27, Epsilon: 0.03
# Episode 689/1000 - Total Reward: 41925437.96, Epsilon: 0.03
# Episode 690/1000 - Total Reward: 41699194.79, Epsilon: 0.03
# Episode 691/1000 - Total Reward: 41886990.05, Epsilon: 0.03
# Episode 692/1000 - Total Reward: 41921476.17, Epsilon: 0.03
# Episode 693/1000 - Total Reward: 41972473.66, Epsilon: 0.03
# Episode 694/1000 - Total Reward: 41773085.27, Epsilon: 0.03
# Episode 695/1000 - Total Reward: 42068904.49, Epsilon: 0.03
# Episode 696/1000 - Total Reward: 41847131.13, Epsilon: 0.03
# Episode 697/1000 - Total Reward: 42092794.54, Epsilon: 0.03
# Episode 698/1000 - Total Reward: 41793996.34, Epsilon: 0.03
# Episode 699/1000 - Total Reward: 42082161.95, Epsilon: 0.03
# Episode 700/1000 - Total Reward: 42011856.33, Epsilon: 0.03
# Episode 701/1000 - Total Reward: 41884054.44, Epsilon: 0.03
# Episode 702/1000 - Total Reward: 41818892.40, Epsilon: 0.03
# Episode 703/1000 - Total Reward: 41964839.39, Epsilon: 0.03
# Episode 704/1000 - Total Reward: 42036563.00, Epsilon: 0.03
# Episode 705/1000 - Total Reward: 41933653.10, Epsilon: 0.03
# Episode 706/1000 - Total Reward: 41914085.29, Epsilon: 0.03
# Episode 707/1000 - Total Reward: 42009906.02, Epsilon: 0.03
# Episode 708/1000 - Total Reward: 42072743.33, Epsilon: 0.03
# Episode 709/1000 - Total Reward: 41728090.34, Epsilon: 0.03
# Episode 710/1000 - Total Reward: 41920838.58, Epsilon: 0.03
# Episode 711/1000 - Total Reward: 41878170.68, Epsilon: 0.03
# Episode 712/1000 - Total Reward: 41977435.11, Epsilon: 0.03
# Episode 713/1000 - Total Reward: 41932334.48, Epsilon: 0.03
# Episode 714/1000 - Total Reward: 42121790.90, Epsilon: 0.03
# Episode 715/1000 - Total Reward: 42128851.93, Epsilon: 0.03
# Episode 716/1000 - Total Reward: 42090070.95, Epsilon: 0.03
# Episode 717/1000 - Total Reward: 41951904.61, Epsilon: 0.03
# Episode 718/1000 - Total Reward: 41775308.01, Epsilon: 0.03
# Episode 719/1000 - Total Reward: 41859780.89, Epsilon: 0.03
# Episode 720/1000 - Total Reward: 41777075.34, Epsilon: 0.03
# Episode 721/1000 - Total Reward: 41948478.94, Epsilon: 0.03
# Episode 722/1000 - Total Reward: 41651112.88, Epsilon: 0.03
# Episode 723/1000 - Total Reward: 42030157.14, Epsilon: 0.03
# Episode 724/1000 - Total Reward: 41898778.35, Epsilon: 0.03
# Episode 725/1000 - Total Reward: 41902382.92, Epsilon: 0.03
# Episode 726/1000 - Total Reward: 41953024.40, Epsilon: 0.03
# Episode 727/1000 - Total Reward: 42037401.57, Epsilon: 0.03
# Episode 728/1000 - Total Reward: 42180572.51, Epsilon: 0.03
# Episode 729/1000 - Total Reward: 41979980.33, Epsilon: 0.03
# Episode 730/1000 - Total Reward: 42165999.31, Epsilon: 0.03
# Episode 731/1000 - Total Reward: 41802368.83, Epsilon: 0.03
# Episode 732/1000 - Total Reward: 41893976.21, Epsilon: 0.03
# Episode 733/1000 - Total Reward: 42039703.63, Epsilon: 0.03
# Episode 734/1000 - Total Reward: 41952307.28, Epsilon: 0.03
# Episode 735/1000 - Total Reward: 41985984.71, Epsilon: 0.02
# Episode 736/1000 - Total Reward: 42004116.72, Epsilon: 0.02
# Episode 737/1000 - Total Reward: 42023648.72, Epsilon: 0.02
# Episode 738/1000 - Total Reward: 42004688.88, Epsilon: 0.02
# Episode 739/1000 - Total Reward: 42065042.20, Epsilon: 0.02
# Episode 740/1000 - Total Reward: 41938503.55, Epsilon: 0.02
# Episode 741/1000 - Total Reward: 42026133.46, Epsilon: 0.02
# Episode 742/1000 - Total Reward: 41982254.81, Epsilon: 0.02
# Episode 743/1000 - Total Reward: 42090228.72, Epsilon: 0.02
# Episode 744/1000 - Total Reward: 41848594.83, Epsilon: 0.02
# Episode 745/1000 - Total Reward: 41922210.96, Epsilon: 0.02
# Episode 746/1000 - Total Reward: 41988843.14, Epsilon: 0.02
# Episode 747/1000 - Total Reward: 41901422.77, Epsilon: 0.02
# Episode 748/1000 - Total Reward: 41884408.25, Epsilon: 0.02
# Episode 749/1000 - Total Reward: 41921813.30, Epsilon: 0.02
# Episode 750/1000 - Total Reward: 41626986.31, Epsilon: 0.02
# Episode 751/1000 - Total Reward: 42037712.97, Epsilon: 0.02
# Episode 752/1000 - Total Reward: 42102385.76, Epsilon: 0.02
# Episode 753/1000 - Total Reward: 41905101.86, Epsilon: 0.02
# Episode 754/1000 - Total Reward: 42129094.12, Epsilon: 0.02
# Episode 755/1000 - Total Reward: 41860615.73, Epsilon: 0.02
# Episode 756/1000 - Total Reward: 41990829.00, Epsilon: 0.02
# Episode 757/1000 - Total Reward: 42038432.33, Epsilon: 0.02
# Episode 758/1000 - Total Reward: 42178734.60, Epsilon: 0.02
# Episode 759/1000 - Total Reward: 41957948.06, Epsilon: 0.02
# Episode 760/1000 - Total Reward: 42059290.95, Epsilon: 0.02
# Episode 761/1000 - Total Reward: 42165039.83, Epsilon: 0.02
# Episode 762/1000 - Total Reward: 42167115.04, Epsilon: 0.02
# Episode 763/1000 - Total Reward: 42078533.61, Epsilon: 0.02
# Episode 764/1000 - Total Reward: 41935439.99, Epsilon: 0.02
# Episode 765/1000 - Total Reward: 42023771.89, Epsilon: 0.02
# Episode 766/1000 - Total Reward: 42017748.89, Epsilon: 0.02
# Episode 767/1000 - Total Reward: 41991995.44, Epsilon: 0.02
# Episode 768/1000 - Total Reward: 41851047.14, Epsilon: 0.02
# Episode 769/1000 - Total Reward: 42011475.32, Epsilon: 0.02
# Episode 770/1000 - Total Reward: 41930480.76, Epsilon: 0.02
# Episode 771/1000 - Total Reward: 41983947.42, Epsilon: 0.02
# Episode 772/1000 - Total Reward: 42212817.89, Epsilon: 0.02
# Episode 773/1000 - Total Reward: 42001741.70, Epsilon: 0.02
# Episode 774/1000 - Total Reward: 42311317.03, Epsilon: 0.02
# Episode 775/1000 - Total Reward: 41885034.80, Epsilon: 0.02
# Episode 776/1000 - Total Reward: 41991028.72, Epsilon: 0.02
# Episode 777/1000 - Total Reward: 41943589.48, Epsilon: 0.02
# Episode 778/1000 - Total Reward: 42033660.21, Epsilon: 0.02
# Episode 779/1000 - Total Reward: 41983414.16, Epsilon: 0.02
# Episode 780/1000 - Total Reward: 42073854.77, Epsilon: 0.02
# Episode 781/1000 - Total Reward: 42087300.91, Epsilon: 0.02
# Episode 782/1000 - Total Reward: 41926378.54, Epsilon: 0.02
# Episode 783/1000 - Total Reward: 41917130.43, Epsilon: 0.02
# Episode 784/1000 - Total Reward: 41871413.25, Epsilon: 0.02
# Episode 785/1000 - Total Reward: 41901609.62, Epsilon: 0.02
# Episode 786/1000 - Total Reward: 42078124.28, Epsilon: 0.02
# Episode 787/1000 - Total Reward: 41988510.30, Epsilon: 0.02
# Episode 788/1000 - Total Reward: 42159888.29, Epsilon: 0.02
# Episode 789/1000 - Total Reward: 41942650.56, Epsilon: 0.02
# Episode 790/1000 - Total Reward: 42029901.67, Epsilon: 0.02
# Episode 791/1000 - Total Reward: 41999984.99, Epsilon: 0.02
# Episode 792/1000 - Total Reward: 41925931.39, Epsilon: 0.02
# Episode 793/1000 - Total Reward: 42012135.52, Epsilon: 0.02
# Episode 794/1000 - Total Reward: 41827911.54, Epsilon: 0.02
# Episode 795/1000 - Total Reward: 42032510.90, Epsilon: 0.02
# Episode 796/1000 - Total Reward: 42153668.23, Epsilon: 0.02
# Episode 797/1000 - Total Reward: 42044213.96, Epsilon: 0.02
# Episode 798/1000 - Total Reward: 42281847.30, Epsilon: 0.02
# Episode 799/1000 - Total Reward: 41999274.25, Epsilon: 0.02
# Episode 800/1000 - Total Reward: 42056848.83, Epsilon: 0.02
# Episode 801/1000 - Total Reward: 42051756.29, Epsilon: 0.02
# Episode 802/1000 - Total Reward: 41943847.13, Epsilon: 0.02
# Episode 803/1000 - Total Reward: 42025351.45, Epsilon: 0.02
# Episode 804/1000 - Total Reward: 41918686.95, Epsilon: 0.02
# Episode 805/1000 - Total Reward: 41926461.78, Epsilon: 0.02
# Episode 806/1000 - Total Reward: 42194408.61, Epsilon: 0.02
# Episode 807/1000 - Total Reward: 42060497.48, Epsilon: 0.02
# Episode 808/1000 - Total Reward: 42026126.29, Epsilon: 0.02
# Episode 809/1000 - Total Reward: 42069668.63, Epsilon: 0.02
# Episode 810/1000 - Total Reward: 41869671.38, Epsilon: 0.02
# Episode 811/1000 - Total Reward: 42065882.02, Epsilon: 0.02
# Episode 812/1000 - Total Reward: 41900186.67, Epsilon: 0.02
# Episode 813/1000 - Total Reward: 41889358.48, Epsilon: 0.02
# Episode 814/1000 - Total Reward: 41909418.85, Epsilon: 0.02
# Episode 815/1000 - Total Reward: 42068243.60, Epsilon: 0.02
# Episode 816/1000 - Total Reward: 41976342.33, Epsilon: 0.02
# Episode 817/1000 - Total Reward: 42057451.82, Epsilon: 0.02
# Episode 818/1000 - Total Reward: 42178075.86, Epsilon: 0.02
# Episode 819/1000 - Total Reward: 42065539.69, Epsilon: 0.02
# Episode 820/1000 - Total Reward: 41816100.25, Epsilon: 0.02
# Episode 821/1000 - Total Reward: 42066037.55, Epsilon: 0.02
# Episode 822/1000 - Total Reward: 41824660.25, Epsilon: 0.02
# Episode 823/1000 - Total Reward: 42109539.44, Epsilon: 0.02
# Episode 824/1000 - Total Reward: 41883164.60, Epsilon: 0.02
# Episode 825/1000 - Total Reward: 42072989.48, Epsilon: 0.02
# Episode 826/1000 - Total Reward: 42042208.42, Epsilon: 0.02
# Episode 827/1000 - Total Reward: 41806910.28, Epsilon: 0.02
# Episode 828/1000 - Total Reward: 42024156.16, Epsilon: 0.02
# Episode 829/1000 - Total Reward: 42052018.05, Epsilon: 0.02
# Episode 830/1000 - Total Reward: 42001770.24, Epsilon: 0.02
# Episode 831/1000 - Total Reward: 41901290.80, Epsilon: 0.02
# Episode 832/1000 - Total Reward: 41891342.42, Epsilon: 0.02
# Episode 833/1000 - Total Reward: 41984298.24, Epsilon: 0.02
# Episode 834/1000 - Total Reward: 41692538.81, Epsilon: 0.02
# Episode 835/1000 - Total Reward: 41970540.60, Epsilon: 0.02
# Episode 836/1000 - Total Reward: 42002577.86, Epsilon: 0.02
# Episode 837/1000 - Total Reward: 41958018.31, Epsilon: 0.01
# Episode 838/1000 - Total Reward: 41838548.39, Epsilon: 0.01
# Episode 839/1000 - Total Reward: 42081110.57, Epsilon: 0.01
# Episode 840/1000 - Total Reward: 42009893.96, Epsilon: 0.01
# Episode 841/1000 - Total Reward: 42127708.58, Epsilon: 0.01
# Episode 842/1000 - Total Reward: 41861502.48, Epsilon: 0.01
# Episode 843/1000 - Total Reward: 42065019.76, Epsilon: 0.01
# Episode 844/1000 - Total Reward: 41785549.30, Epsilon: 0.01
# Episode 845/1000 - Total Reward: 41851745.36, Epsilon: 0.01
# Episode 846/1000 - Total Reward: 42042378.58, Epsilon: 0.01
# Episode 847/1000 - Total Reward: 42109919.93, Epsilon: 0.01
# Episode 848/1000 - Total Reward: 42128279.75, Epsilon: 0.01
# Episode 849/1000 - Total Reward: 41950253.61, Epsilon: 0.01
# Episode 850/1000 - Total Reward: 41967045.84, Epsilon: 0.01
# Episode 851/1000 - Total Reward: 41975441.98, Epsilon: 0.01
# Episode 852/1000 - Total Reward: 42138339.67, Epsilon: 0.01
# Episode 853/1000 - Total Reward: 41938417.47, Epsilon: 0.01
# Episode 854/1000 - Total Reward: 41999605.65, Epsilon: 0.01
# Episode 855/1000 - Total Reward: 42130118.22, Epsilon: 0.01
# Episode 856/1000 - Total Reward: 41994775.95, Epsilon: 0.01
# Episode 857/1000 - Total Reward: 42018934.09, Epsilon: 0.01
# Episode 858/1000 - Total Reward: 42121473.24, Epsilon: 0.01
# Episode 859/1000 - Total Reward: 41829983.97, Epsilon: 0.01
# Episode 860/1000 - Total Reward: 42122285.20, Epsilon: 0.01
# Episode 861/1000 - Total Reward: 42125008.67, Epsilon: 0.01
# Episode 862/1000 - Total Reward: 42070059.28, Epsilon: 0.01
# Episode 863/1000 - Total Reward: 41957940.34, Epsilon: 0.01
# Episode 864/1000 - Total Reward: 42077693.96, Epsilon: 0.01
# Episode 865/1000 - Total Reward: 41971235.11, Epsilon: 0.01
# Episode 866/1000 - Total Reward: 41970454.55, Epsilon: 0.01
# Episode 867/1000 - Total Reward: 42183157.53, Epsilon: 0.01
# Episode 868/1000 - Total Reward: 42015579.75, Epsilon: 0.01
# Episode 869/1000 - Total Reward: 41995789.42, Epsilon: 0.01
# Episode 870/1000 - Total Reward: 41938145.30, Epsilon: 0.01
# Episode 871/1000 - Total Reward: 41988223.40, Epsilon: 0.01
# Episode 872/1000 - Total Reward: 42064897.23, Epsilon: 0.01
# Episode 873/1000 - Total Reward: 42119447.66, Epsilon: 0.01
# Episode 874/1000 - Total Reward: 41965543.61, Epsilon: 0.01
# Episode 875/1000 - Total Reward: 42059145.34, Epsilon: 0.01
# Episode 876/1000 - Total Reward: 41942574.74, Epsilon: 0.01
# Episode 877/1000 - Total Reward: 41958812.50, Epsilon: 0.01
# Episode 878/1000 - Total Reward: 42107719.31, Epsilon: 0.01
# Episode 879/1000 - Total Reward: 42080543.45, Epsilon: 0.01
# Episode 880/1000 - Total Reward: 41926964.75, Epsilon: 0.01
# Episode 881/1000 - Total Reward: 41751673.04, Epsilon: 0.01
# Episode 882/1000 - Total Reward: 42166042.20, Epsilon: 0.01
# Episode 883/1000 - Total Reward: 41871179.65, Epsilon: 0.01
# Episode 884/1000 - Total Reward: 42018429.62, Epsilon: 0.01
# Episode 885/1000 - Total Reward: 42210506.75, Epsilon: 0.01
# Episode 886/1000 - Total Reward: 42077162.03, Epsilon: 0.01
# Episode 887/1000 - Total Reward: 42130977.05, Epsilon: 0.01
# Episode 888/1000 - Total Reward: 42009792.39, Epsilon: 0.01
# Episode 889/1000 - Total Reward: 42023430.83, Epsilon: 0.01
# Episode 890/1000 - Total Reward: 42098261.21, Epsilon: 0.01
# Episode 891/1000 - Total Reward: 42015620.15, Epsilon: 0.01
# Episode 892/1000 - Total Reward: 42011838.00, Epsilon: 0.01
# Episode 893/1000 - Total Reward: 42158308.40, Epsilon: 0.01
# Episode 894/1000 - Total Reward: 41650076.20, Epsilon: 0.01
# Episode 895/1000 - Total Reward: 41899504.59, Epsilon: 0.01
# Episode 896/1000 - Total Reward: 42114974.41, Epsilon: 0.01
# Episode 897/1000 - Total Reward: 42110881.91, Epsilon: 0.01
# Episode 898/1000 - Total Reward: 41928176.38, Epsilon: 0.01
# Episode 899/1000 - Total Reward: 42082308.82, Epsilon: 0.01
# Episode 900/1000 - Total Reward: 41841681.94, Epsilon: 0.01
# Episode 901/1000 - Total Reward: 41759949.21, Epsilon: 0.01
# Episode 902/1000 - Total Reward: 41791702.40, Epsilon: 0.01
# Episode 903/1000 - Total Reward: 41924391.53, Epsilon: 0.01
# Episode 904/1000 - Total Reward: 42007826.28, Epsilon: 0.01
# Episode 905/1000 - Total Reward: 42209126.65, Epsilon: 0.01
# Episode 906/1000 - Total Reward: 41993125.93, Epsilon: 0.01
# Episode 907/1000 - Total Reward: 42040913.64, Epsilon: 0.01
# Episode 908/1000 - Total Reward: 42098928.10, Epsilon: 0.01
# Episode 909/1000 - Total Reward: 42019691.46, Epsilon: 0.01
# Episode 910/1000 - Total Reward: 41859592.56, Epsilon: 0.01
# Episode 911/1000 - Total Reward: 41993154.36, Epsilon: 0.01
# Episode 912/1000 - Total Reward: 42003198.13, Epsilon: 0.01
# Episode 913/1000 - Total Reward: 42010505.62, Epsilon: 0.01
# Episode 914/1000 - Total Reward: 42101038.16, Epsilon: 0.01
# Episode 915/1000 - Total Reward: 42235415.09, Epsilon: 0.01
# Episode 916/1000 - Total Reward: 41873870.28, Epsilon: 0.01
# Episode 917/1000 - Total Reward: 42054260.10, Epsilon: 0.01
# Episode 918/1000 - Total Reward: 42097469.12, Epsilon: 0.01
# Episode 919/1000 - Total Reward: 42009432.68, Epsilon: 0.01
# Episode 920/1000 - Total Reward: 42045127.00, Epsilon: 0.01
# Episode 921/1000 - Total Reward: 41934007.57, Epsilon: 0.01
# Episode 922/1000 - Total Reward: 42046501.08, Epsilon: 0.01
# Episode 923/1000 - Total Reward: 42000472.72, Epsilon: 0.01
# Episode 924/1000 - Total Reward: 41927367.42, Epsilon: 0.01
# Episode 925/1000 - Total Reward: 42004168.77, Epsilon: 0.01
# Episode 926/1000 - Total Reward: 41898780.98, Epsilon: 0.01
# Episode 927/1000 - Total Reward: 41946686.87, Epsilon: 0.01
# Episode 928/1000 - Total Reward: 42027243.82, Epsilon: 0.01
# Episode 929/1000 - Total Reward: 42060638.95, Epsilon: 0.01
# Episode 930/1000 - Total Reward: 42071649.75, Epsilon: 0.01
# Episode 931/1000 - Total Reward: 41969982.01, Epsilon: 0.01
# Episode 932/1000 - Total Reward: 41819705.40, Epsilon: 0.01
# Episode 933/1000 - Total Reward: 41757465.04, Epsilon: 0.01
# Episode 934/1000 - Total Reward: 41816488.34, Epsilon: 0.01
# Episode 935/1000 - Total Reward: 42106136.26, Epsilon: 0.01
# Episode 936/1000 - Total Reward: 41915983.94, Epsilon: 0.01
# Episode 937/1000 - Total Reward: 42026859.53, Epsilon: 0.01
# Episode 938/1000 - Total Reward: 42054776.25, Epsilon: 0.01
# Episode 939/1000 - Total Reward: 42065243.23, Epsilon: 0.01
# Episode 940/1000 - Total Reward: 41824331.65, Epsilon: 0.01
# Episode 941/1000 - Total Reward: 41987034.35, Epsilon: 0.01
# Episode 942/1000 - Total Reward: 42064415.01, Epsilon: 0.01
# Episode 943/1000 - Total Reward: 42134192.78, Epsilon: 0.01
# Episode 944/1000 - Total Reward: 42103025.82, Epsilon: 0.01
# Episode 945/1000 - Total Reward: 42132322.06, Epsilon: 0.01
# Episode 946/1000 - Total Reward: 42035722.08, Epsilon: 0.01
# Episode 947/1000 - Total Reward: 41866908.40, Epsilon: 0.01
# Episode 948/1000 - Total Reward: 42011875.62, Epsilon: 0.01
# Episode 949/1000 - Total Reward: 42068263.84, Epsilon: 0.01
# Episode 950/1000 - Total Reward: 42103366.37, Epsilon: 0.01
# Episode 951/1000 - Total Reward: 41968781.37, Epsilon: 0.01
# Episode 952/1000 - Total Reward: 42193126.53, Epsilon: 0.01
# Episode 953/1000 - Total Reward: 42083794.20, Epsilon: 0.01
# Episode 954/1000 - Total Reward: 42064071.65, Epsilon: 0.01
# Episode 955/1000 - Total Reward: 42053975.29, Epsilon: 0.01
# Episode 956/1000 - Total Reward: 42162826.77, Epsilon: 0.01
# Episode 957/1000 - Total Reward: 42064311.88, Epsilon: 0.01
# Episode 958/1000 - Total Reward: 41976178.22, Epsilon: 0.01
# Episode 959/1000 - Total Reward: 41876162.31, Epsilon: 0.01
# Episode 960/1000 - Total Reward: 42088712.37, Epsilon: 0.01
# Episode 961/1000 - Total Reward: 42063519.22, Epsilon: 0.01
# Episode 962/1000 - Total Reward: 41918970.84, Epsilon: 0.01
# Episode 963/1000 - Total Reward: 42133424.68, Epsilon: 0.01
# Episode 964/1000 - Total Reward: 41878551.09, Epsilon: 0.01
# Episode 965/1000 - Total Reward: 42060831.97, Epsilon: 0.01
# Episode 966/1000 - Total Reward: 41836638.25, Epsilon: 0.01
# Episode 967/1000 - Total Reward: 41875204.56, Epsilon: 0.01
# Episode 968/1000 - Total Reward: 41937646.75, Epsilon: 0.01
# Episode 969/1000 - Total Reward: 42191611.40, Epsilon: 0.01
# Episode 970/1000 - Total Reward: 41817798.64, Epsilon: 0.01
# Episode 971/1000 - Total Reward: 42027036.35, Epsilon: 0.01
# Episode 972/1000 - Total Reward: 42007498.18, Epsilon: 0.01
# Episode 973/1000 - Total Reward: 42085935.54, Epsilon: 0.01
# Episode 974/1000 - Total Reward: 42086791.88, Epsilon: 0.01
# Episode 975/1000 - Total Reward: 42024463.92, Epsilon: 0.01
# Episode 976/1000 - Total Reward: 42043019.11, Epsilon: 0.01
# Episode 977/1000 - Total Reward: 41581160.18, Epsilon: 0.01
# Episode 978/1000 - Total Reward: 42226210.41, Epsilon: 0.01
# Episode 979/1000 - Total Reward: 41858588.99, Epsilon: 0.01
# Episode 980/1000 - Total Reward: 41929303.09, Epsilon: 0.01
# Episode 981/1000 - Total Reward: 41939127.40, Epsilon: 0.01
# Episode 982/1000 - Total Reward: 41963358.43, Epsilon: 0.01
# Episode 983/1000 - Total Reward: 42088353.15, Epsilon: 0.01
# Episode 984/1000 - Total Reward: 41996856.26, Epsilon: 0.01
# Episode 985/1000 - Total Reward: 41960126.64, Epsilon: 0.01
# Episode 986/1000 - Total Reward: 42068587.17, Epsilon: 0.01
# Episode 987/1000 - Total Reward: 42076102.62, Epsilon: 0.01
# Episode 988/1000 - Total Reward: 41860289.19, Epsilon: 0.01
# Episode 989/1000 - Total Reward: 42038241.87, Epsilon: 0.01
# Episode 990/1000 - Total Reward: 41770128.68, Epsilon: 0.01
# Episode 991/1000 - Total Reward: 42027038.61, Epsilon: 0.01
# Episode 992/1000 - Total Reward: 42276449.30, Epsilon: 0.01
# Episode 993/1000 - Total Reward: 42098465.34, Epsilon: 0.01
# Episode 994/1000 - Total Reward: 42151448.90, Epsilon: 0.01
# Episode 995/1000 - Total Reward: 41960064.14, Epsilon: 0.01
# Episode 996/1000 - Total Reward: 42087753.65, Epsilon: 0.01
# Episode 997/1000 - Total Reward: 42029922.37, Epsilon: 0.01
# Episode 998/1000 - Total Reward: 42038976.78, Epsilon: 0.01
# Episode 999/1000 - Total Reward: 42184211.25, Epsilon: 0.01

# %%
env.EnergyHarvestinmg_eta
# Out:
# 0.5
